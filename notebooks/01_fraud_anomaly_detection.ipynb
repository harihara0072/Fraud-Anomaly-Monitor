# %% [markdown]
# # Fraud Anomaly Monitor — SCS 3253 Term Project
#
# Report outline this notebook mirrors: Objective -> Data Preparation -> Model Design -> Model Evaluation -> Conclusions.
# See `docs/fraud-anomaly-monitor-proposal.md` for the full design.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent / "src"))

import pandas as pd

from fraud_anomaly.data import (
    load_cards,
    load_fraud_labels,
    load_mcc_codes,
    load_transactions,
    load_users,
)

# %% [markdown]
# ## 1. Objective
#
# We detect anomalous (potentially fraudulent) transactions using unsupervised anomaly detection, trained without fraud labels, then evaluate the anomaly signal against held-out ground-truth fraud labels.

# %% [markdown]
# ## 2. Data Preparation
#
# Loading a small sample for the skeleton check below (`nrows=5000`); the full-scale load happens once modeling starts.

# %%
users = load_users()
cards = load_cards()
transactions = load_transactions(nrows=5000)
mcc_codes = load_mcc_codes()
fraud_labels = load_fraud_labels()

print("users:", users.shape)
print("cards:", cards.shape)
print("transactions (sample):", transactions.shape)
print("mcc codes:", len(mcc_codes))
print("fraud labels:", fraud_labels.shape, "| fraud rate:", fraud_labels.mean())
# Out:
# users: (2000, 14)
# cards: (6146, 13)
# transactions (sample): (5000, 12)
# mcc codes: 109
# fraud labels: (8914963,) | fraud rate: 0.0014954633014180765

# %% [markdown]
# ## 3. Model Design
#
# ### 3.1 Isolation Forest
#
# ### 3.2 One-Class SVM
#
# ### 3.3 Autoencoder

# %% [markdown]
# ## 4. Model Evaluation

# %% [markdown]
# ## 5. Conclusions
